# %% [markdown]
# converting tabular data to tensors

# %%
wine_path = "wine.csv"
import numpy as np
import torch
import csv
mpy = np.loadtxt(wine_path, dtype=np.float32, delimiter=";", skiprows=1)
sor = torch.from_numpy(mpy)
data = sor[:,:-1]
result = sor[:,-1]
result.shape

#arr.max(), np.min(arr)
#data, result
# Out:
# torch.Size([4898])

# %% [markdown]
# one hot encodding

# %% [markdown]
# normalizing data
